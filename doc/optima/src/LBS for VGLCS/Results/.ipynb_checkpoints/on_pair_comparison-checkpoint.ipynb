# %%
import pandas as pd
import re
import os

# ---- Учитај фајлове ----
df1 = pd.read_csv("results_16_train_instances_m2/IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10.csv")  #")  #"IMSBS-2000_heuristic-h5_imbs-iters-500_num-roots-10.csv")  
#df2 = pd.read_csv("tuningExpanded/LIMSBS-1000_imbs-iters-1000_num-roots-10_U10_10_10_A2_F1.csv")   #LIMSBS-1000_imbs-iters-1000_num-roots-10_U10_10_10_A2_F2.csv") #"LIMSBS-2000_imbs-iters-500_num-roots-10_U5_5_5_A2_F3.csv") #"learning_U10_5_5_A2_F3.csv")   #LIMSBS-1000_imbs-iters-500_num-roots-10_U5_5_5_A1_F3.csv
df2=pd.read_csv("results_16_train_instances_m10/LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_5_A2_F3.csv") #LIMSBS-1000_imbs-iters-1000_num-roots-10_U10_10_5_A2_F3.csv")

# TODO (executed experiments): LIMSBS-1000_imbs-iters-500_num-roots-10 U10 5 5 A2 F3

# ---- Извуци 4 броја из имена фајла ----
def extract_numbers(filename):
    # узимамо сва 4 броја из имена: n_m_k_index
    m = re.match(r".*?_(\d+)_(\d+)_(\d+)_(\d+)\.txt\.out", filename)
    if m:
        return int(m.group(1)), int(m.group(2)), int(m.group(3)), int(m.group(4))
    else:
        return None, None, None, None

for df in [df1, df2]:
    df[['n','m','k','idx']] = df['file'].apply(lambda x: pd.Series(extract_numbers(x)))
    # kreiramo key po prva tri broja
    df['key'] = df[['n','m','k']].astype(str).agg('_'.join, axis=1)

# ---- Spoji podatke po key ----
merged = pd.merge(df1, df2, on='key', suffixes=('_1','_2'))

# ---- Agregiraj po prva tri broja (key) ----
agg = merged.groupby('key').agg({
    'time_1': 'mean',
    'quality_1': 'mean',
    'time_2': 'mean',
    'quality_2': 'mean'
}).reset_index()

# ---- Sačuvaj u CSV ----
#agg.to_csv("merged_aggregated.csv", index=False)

# ---- Rezultat ----
agg = agg.rename(columns={"quality_1" : "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "time_1": "IMSBS-time", "quality_2": "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_5_A2_F3", "time_2": "LIMSBS-time"})

# %%
agg[["key", "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_5_A2_F3", "IMSBS-time", "LIMSBS-time" ]].mean() #.to_latex("results_preliminary.tex", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 agg[["key", "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_5_A2_F3", "IMSBS-time", "LIMSBS-time" ]].mean() #.to_latex("results_preliminary.tex", index=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
#64.596875 (LIMSBS) vs. 63.668750 (IMSBS)

# %%
agg_res = agg[["key", "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_5_5_A3_F1"]]

# %%
agg_res.to_latex("results_IMSBS_LBS.tex", index=False)
# Out:
# /tmp/ipykernel_12046/3693479938.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   agg_res.to_latex("results_IMSBS_LBS.tex", index=False)

# %%
agg_res
# Out:
#          key  IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10  \
# 0   10_100_2                                               11.3
# 1   10_100_4                                                8.1
# 2   10_200_2                                               12.6
# 3   10_200_4                                                7.9
# 4   10_500_2                                               12.8
# 5   10_500_4                                                8.4
# 6    10_50_2                                               11.6
# 7    10_50_4                                                7.4
# 8    2_100_2                                               72.8
# 9    2_100_4                                               61.7
# 10   2_200_2                                              136.9
# 11   2_200_4                                              125.1
# 12   2_500_2                                              272.1
# 13   2_500_4                                              299.3
# ...
