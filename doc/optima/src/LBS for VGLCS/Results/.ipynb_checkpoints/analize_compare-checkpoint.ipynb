# %%
import pandas as pd
import glob
import os
import re

# =====================================
# Collect all learning CSVs
# =====================================
learning_files = sorted(glob.glob("results_16_train_instances_m3/*.csv"))#tuning2 tuningExpanded tuning_m_2_3 results_16_train_instances_m3 newTuningWithValidation/LIMSBS-500_imbs-iters-3000_num-roots-10_U10_5_5_A2_F2 

print("Found files:")
for f in learning_files:
    print(" ", f)

dfs = []

# =====================================
# Load each CSV as one column
# =====================================
for f in learning_files:

    name = os.path.splitext(os.path.basename(f))[0]   # column name

    df = pd.read_csv(f)

    # use instance filename as key
    df = df[['file','quality']]

    df = df.rename(columns={'quality': name})

    dfs.append(df.set_index('file'))


# =====================================
# Merge column-wise on file
# =====================================
result = pd.concat(dfs, axis=1)

# =====================================
# Optional: sort rows
# =====================================
result = result.sort_index()

print("\nFinal dataframe:")
print(result.head())


# =====================================
# Save
# =====================================
result.to_csv("summary_learning_objectives_matrix.txt")

#print("\nSaved learning_objectives_matrix.csv")
# Out:
# Found files:
#   results_16_train_instances_m3/IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10-1.csv
#   results_16_train_instances_m3/IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10.csv
#   results_16_train_instances_m3/LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A1_F2.csv
#   results_16_train_instances_m3/LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F1.csv
#   results_16_train_instances_m3/LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2.csv
#   results_16_train_instances_m3/learning_U10_10_10_A1_F1.csv
#   results_16_train_instances_m3/learning_U10_10_10_A1_F2.csv
#   results_16_train_instances_m3/learning_U10_10_10_A1_F3.csv
#   results_16_train_instances_m3/learning_U10_10_10_A2_F1.csv
#   results_16_train_instances_m3/learning_U10_10_10_A2_F2.csv
#   results_16_train_instances_m3/learning_U10_10_10_A3_F1.csv
#   results_16_train_instances_m3/learning_U10_10_5_A2_F2.csv
#   results_16_train_instances_m3/learning_U10_5_5_A1_F1.csv
# ...

# %%
# =====================================
# Load previous result
# =====================================
df = pd.read_csv("summary_learning_objectives_matrix.txt")

# first column is 'file'
df = df.set_index('file')


# =====================================
# Extract category = first three numbers
# =====================================
def extract_category(name):
    # matches ..._10_10_10.3  or ..._10_10_10_3
    m = re.search(r"(\d+)_(\d+)_(\d+)[\._]", str(name))
    if m:
        return f"{m.group(1)}_{m.group(2)}_{m.group(3)}"
    return None


df['category'] = df.index.map(extract_category)

# =====================================
# Group by category and average instances
# =====================================
grouped = df.groupby('category').mean(numeric_only=True)

#print(grouped.head())


# =====================================
# Save
# =====================================
#grouped.to_csv("summary_learning_objectives_grouped.csv")

#print("\nSaved learning_objectives_grouped.csv")

# %%
grouped.mean().head(60)
# Out:
# IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10-1      65.928125
# IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10        65.928125
# LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A1_F2    66.684375
# LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F1    66.709375
# LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2    61.888825
# learning_U10_10_10_A1_F1                                   60.028125
# learning_U10_10_10_A1_F2                                   61.881250
# learning_U10_10_10_A1_F3                                   58.734028
# learning_U10_10_10_A2_F1                                   62.207292
# learning_U10_10_10_A2_F2                                   62.468750
# learning_U10_10_10_A3_F1                                   58.493750
# learning_U10_10_5_A2_F2                                    61.746875
# learning_U10_5_5_A1_F1                                     57.915625
# learning_U10_5_5_A1_F2                                     58.884375
# ...

# %%
#learning_U5_5_5_A2_F1, 
grouped=grouped.reset_index()
grouped.columns
# Out:
# Index(['category', 'IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10-1',
#        'IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10',
#        'LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A1_F2',
#        'LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F1',
#        'LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2',
#        'learning_U10_10_10_A1_F1', 'learning_U10_10_10_A1_F2',
#        'learning_U10_10_10_A1_F3', 'learning_U10_10_10_A2_F1',
#        'learning_U10_10_10_A2_F2', 'learning_U10_10_10_A3_F1',
#        'learning_U10_10_5_A2_F2', 'learning_U10_5_5_A1_F1',
#        'learning_U10_5_5_A1_F2', 'learning_U10_5_5_A3_F2',
#        'learning_U10_5_5_A3_F3', 'learning_U5_5_5_A1_F1',
#        'learning_U5_5_5_A3_F1', 'learning_U5_5_5_A3_F2',
#        'learning_U5_5_5_A3_F3'],
#       dtype='object')

# %%
#THE BEST CONFIGS OF FFNN: learning_U5_5_5_A1_F3 (62.45), learning_U5_5_5_A2_F1   62.175000, learning_U5_5_5_A3_F1 62.18
#m=10:# rouped_compare = grouped[[ "category",  "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_5_A2_F3" ]] #"learning_basic_imsbs"]]
#m=5:# grouped_compare = grouped[[ "category",  "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_5_5_A3_F1" ]] #"learning_basic_imsbs"]]

# m=3: TODO: make it better (LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2)

grouped_compare = grouped[[ "category",  "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2" ]] #"learning_basic_imsbs"]]

#m=2: grouped_compare = grouped[[ "category",  "IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10", "LIMSBS-500_imbs-iters-3000_num-roots-10_U10_5_5_A2_F2" ]] #"learning_basic_imsbs"]]

# %%
grouped_compare #[grouped_compare["category"].str.split("_")[0] == "10"]
# Out:
#     category  IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10  \
# 0   10_100_2                                               11.3
# 1   10_100_4                                                8.1
# 2   10_200_2                                               12.6
# 3   10_200_4                                                7.9
# 4   10_500_2                                               12.8
# 5   10_500_4                                                8.4
# 6    10_50_2                                               11.6
# 7    10_50_4                                                7.4
# 8    2_100_2                                               72.8
# 9    2_100_4                                               61.7
# 10   2_200_2                                              136.9
# 11   2_200_4                                              125.1
# 12   2_500_2                                              272.1
# 13   2_500_4                                              299.3
# ...

# %%
grouped_compare.mean()
# Out:
# category                                                   3.156316e+157
# IMSBS-500_heuristic-h5_imbs-iters-3000_num-roots-10         6.592812e+01
# LIMSBS-500_imbs-iters-3000_num-roots-10_U10_10_10_A2_F2     6.188882e+01
# dtype: float64

# %%
#extract_results = grouped[[ "category", "learning_U5_5_5_A2_F3", "IMSBS-1000_heuristic-h5_imbs-iters-1000_num-roots-10", "LIMSBS-1000_imbs-iters-1000_num-roots-10_U10_10_5_A2_F1" ]] #"learning_basic_imsbs"]]

# %%
#extract_results.to_latex("results_preliminary.tex", index=False)

# %%
#extract_results
